# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
WildBlueberryPollinationSimulationData_dataset=pd.read_csv("WildBlueberryPollinationSimulationData.csv")

# %%
WildBlueberryPollinationSimulationData_dataset
# Out:
#      Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       0       37.5     0.750    0.250    0.250  0.250              86.0
# 1       1       37.5     0.750    0.250    0.250  0.250              86.0
# 2       2       37.5     0.750    0.250    0.250  0.250              94.6
# 3       3       37.5     0.750    0.250    0.250  0.250              94.6
# 4       4       37.5     0.750    0.250    0.250  0.250              86.0
# ..    ...        ...       ...      ...      ...    ...               ...
# 772   772       10.0     0.537    0.117    0.409  0.058              86.0
# 773   773       40.0     0.537    0.117    0.409  0.058              86.0
# 774   774       20.0     0.537    0.117    0.409  0.058              86.0
# 775   775       20.0     0.537    0.117    0.409  0.058              89.0
# 776   776       20.0     0.537    0.117    0.409  0.058              89.0
#
#      MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# ...

# %%
WildBlueberryPollinationSimulationData_dataset.shape
# Out:
# (777, 18)

# %%
WildBlueberryPollinationSimulationData_dataset.head()
# Out:
#    Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0     0       37.5      0.75     0.25     0.25   0.25              86.0
# 1     1       37.5      0.75     0.25     0.25   0.25              86.0
# 2     2       37.5      0.75     0.25     0.25   0.25              94.6
# 3     3       37.5      0.75     0.25     0.25   0.25              94.6
# 4     4       37.5      0.75     0.25     0.25   0.25              86.0
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              52.0                  71.9              62.0              30.0
# 2              57.2                  79.0              68.2              33.0
# 3              57.2                  79.0              68.2              33.0
# 4              52.0                  71.9              62.0              30.0
#
# ...

# %%
WildBlueberryPollinationSimulationData_dataset=WildBlueberryPollinationSimulationData_dataset.drop(['Row#','clonesize','honeybee','bumbles','andrena','osmia','MaxOfUpperTRange','MinOfUpperTRange','AverageOfUpperTRange','MaxOfLowerTRange','MinOfLowerTRange','AverageOfLowerTRange','RainingDays','AverageRainingDays','fruitset','fruitmass'],axis=1)

# %%
WildBlueberryPollinationSimulationData_dataset
# Out:
#          seeds        yield
# 0    31.678898  3813.165795
# 1    33.449385  4947.605663
# 2    30.546306  3866.798965
# 3    31.562586  4303.943030
# 4    28.873714  3436.493543
# ..         ...          ...
# 772  33.447471  5333.873335
# 773  28.462005  3373.436842
# 774  30.748240  4203.027624
# 775  30.582161  4166.299735
# 776  29.742583  3943.131681
#
# [777 rows x 2 columns]

# %%
x=WildBlueberryPollinationSimulationData_dataset.iloc[:,0]

# %%
x.shape
# Out:
# (777,)

# %%
x=WildBlueberryPollinationSimulationData_dataset.iloc[:,0].values.reshape(-1,1)

# %%
x.shape
# Out:
# (777, 1)

# %%
x
# Out:
# array([[31.67889844],
#        [33.44938499],
#        [30.54630597],
#        [31.56258602],
#        [28.87371362],
#        [27.3454535 ],
#        [26.10117938],
#        [25.0423614 ],
#        [32.33415267],
#        [34.8499528 ],
#        [29.07835591],
#        [31.59741611],
#        [33.53267475],
#        [30.12462708],
#        [30.79374092],
#        [29.55021089],
#        [26.48732245],
#        [26.28235597],
#        [24.32062733],
#        [33.29902167],
#        [34.70788043],
#        [30.88504716],
#        [29.84228529],
#        [31.10924166],
#        [29.2486781 ],
#        [33.11609108],
#        [34.46756739],
#        [31.66559817],
#        [32.46088718],
#        [30.21832512],
#        [27.8743632 ],
#        [27.40175511],
#        [25.43353016],
#        [33.58954163],
#        [36.61704886],
#        [30.54294428],
#        [33.30696962],
#        [32.84923819],
#        [31.1279858 ],
#        [27.62154773],
#        [33.4416065 ],
# ...

# %%
y=WildBlueberryPollinationSimulationData_dataset.iloc[:,-1].values.reshape(-1,1)

# %%
y.shape
# Out:
# (777, 1)

# %%
y
# Out:
# array([[3813.165795],
#        [4947.605663],
#        [3866.798965],
#        [4303.94303 ],
#        [3436.493543],
#        [2825.003738],
#        [2625.269164],
#        [2379.905214],
#        [4234.868585],
#        [5356.871861],
#        [4057.555205],
#        [3941.255122],
#        [4768.594369],
#        [3720.711588],
#        [3900.344042],
#        [3387.785165],
#        [2688.028831],
#        [2508.375673],
#        [1945.530615],
#        [4310.625398],
#        [4830.959809],
#        [3911.422247],
#        [4051.551293],
#        [3837.512961],
#        [3269.271761],
#        [4503.161856],
#        [5126.993178],
#        [4248.355054],
#        [4476.811464],
#        [3662.183125],
#        [2988.05944 ],
#        [3049.260316],
#        [2384.728916],
#        [4898.835857],
#        [5831.7066  ],
#        [4334.841218],
#        [5246.521458],
#        [4356.945873],
#        [3822.981667],
#        [3182.698648],
#        [4870.625368],
# ...

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (621, 1)

# %%
x_test.shape
# Out:
# (156, 1)

# %%
y_train.shape
# Out:
# (621, 1)

# %%
y_test.shape
# Out:
# (156, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lm.predict(x_test)

# %%
y_pred
# Out:
# array([[6840.54440918],
#        [4481.89255419],
#        [6682.67246584],
#        [4418.64387277],
#        [4691.16567777],
#        [6543.87237195],
#        [5334.49029511],
#        [7504.3800262 ],
#        [9155.250879  ],
#        [5210.58022803],
#        [3401.22046939],
#        [6244.46688873],
#        [6120.13593294],
#        [4355.1806587 ],
#        [6951.99283812],
#        [6628.66663479],
#        [6639.03715015],
#        [8014.25076906],
#        [6950.32631141],
#        [4419.20538966],
#        [6762.45497362],
#        [7925.71349124],
#        [6863.65299586],
#        [6437.00331832],
#        [4680.15675055],
#        [6363.38120004],
#        [5568.7409168 ],
#        [6229.4607486 ],
#        [4561.00700313],
#        [6142.68961061],
#        [4519.56840434],
#        [8306.37323094],
#        [5392.06688031],
#        [6725.29581294],
#        [9021.56948407],
#        [5546.9478053 ],
#        [7300.90820794],
#        [5889.43330227],
# ...

# %%
check=pd.DataFrame(x_test,columns=['seeds'])

# %%
check['COA Actual']=y_test

# %%
check['COA Predicted']=y_pred

# %%
check
# Out:
#          seeds   COA Actual  COA Predicted
# 0    38.868110  6795.881873    6840.544409
# 1    31.004606  4357.822918    4481.892554
# 2    38.341781  7293.536170    6682.672466
# 3    30.793741  3900.344042    4418.643873
# 4    31.702301  4387.741853    4691.165678
# ..         ...          ...            ...
# 151  45.069192  8284.854610    8700.553939
# 152  35.756223  5700.243243    5907.136487
# 153  36.249695  6920.084268    6055.152780
# 154  40.546480  7560.205645    7343.969934
# 155  41.545825  7835.767792    7643.722917
#
# [156 rows x 3 columns]

# %%
plt.scatter(x,y,color='pink')
plt.plot(x_test,y_pred,color='blue')

# %%
plt.scatter(x_test,y_test,color='orange')
plt.plot(x_test,y_pred,color='green')
